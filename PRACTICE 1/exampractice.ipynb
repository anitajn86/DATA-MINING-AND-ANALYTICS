# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("Bike_Sales_New.xlsx")

# %%
text=" ".join(data["Country"])
text
# Out:
# 'United States Germany United States France Germany France France Germany France Germany Australia United States Germany Germany Germany Australia United States France Australia Australia United States Australia Germany Australia United States United Kingdom Australia Canada United Kingdom Australia Germany Australia Australia Germany Australia France United States Australia United States Australia Germany United Kingdom Australia United Kingdom Australia Australia Germany United Kingdom United States United States Australia Germany Australia Australia United Kingdom Australia Australia United States Australia Australia Australia United Kingdom United States Germany Germany United States Germany United Kingdom United Kingdom Germany United States Australia Australia United Kingdom Australia Australia Germany France Germany United Kingdom United States France France Germany Australia Australia United States Germany United Kingdom Australia Germany Germany United States United States U
# ...

# %%
from wordcloud import WordCloud

# %%
wordcloud=WordCloud(background_color="green").generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
data.head(10)
# Out:
#          Date  Day Month  Year  Customer_Age             Age_Group  \
# 0  2018-07-01    1  July  2018            33  Young Adults (25-34)
# 1  2018-07-01    1  July  2018            41        Adults (35-64)
# 2  2018-07-01    1  July  2018            33  Young Adults (25-34)
# 3  2018-07-01    1  July  2018            37        Adults (35-64)
# 4  2018-07-01    1  July  2018            30  Young Adults (25-34)
# 5  2018-07-01    1  July  2018            42        Adults (35-64)
# 6  2018-07-01    1  July  2018            42        Adults (35-64)
# 7  2018-07-01    1  July  2018            19           Youth (<25)
# 8  2018-07-01    1  July  2018            37        Adults (35-64)
# 9  2018-07-01    1  July  2018            19           Youth (<25)
#
#   Customer_Gender        Country                State Product_Category  \
# 0               F  United States           Washington      Accessories
# 1               M        Germany               Hessen      Accessories
# ...

# %%
Profit_for_the_ages=data.groupby(data['Age_Group'])['Profit'].sum()
Profit_for_the_ages
# Out:
# Age_Group
# Adults (35-64)          2973838
# Seniors (64+)             16232
# Young Adults (25-34)    1978069
# Youth (<25)              930904
# Name: Profit, dtype: int64

# %%
Revenue_by_state=data.groupby(data['State'])['Revenue'].agg(['sum','mean'])
Revenue_by_state
# Out:
#                          sum        mean
# State
# Alabama                  210   52.500000
# Alberta                 4229  128.151515
# Arizona                   99   49.500000
# Bayern                127024  154.155340
# Brandenburg            16322  158.466019
# British Columbia     1439360  141.794897
# California           2085061  148.371237
# Charente-Maritime      13872  152.439560
# England              1140349  141.905052
# Essonne                80452  139.431542
# Florida                 1573  157.300000
# Garonne (Haute)        16615  137.314050
# Georgia                 1257  209.500000
# Hamburg               176598  165.353933
# Hauts de Seine         92736  144.000000
# Hessen                192823  144.870774
# Illinois                5453  227.208333
# Kentucky                1202  240.400000
# Loir et Cher           10300  137.333333
# Loiret                 31031  141.050000
# Minnesota                208   52.000000
# Mississippi              240  120.000000
# ...

# %%
data.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
data['Date']=data['Date'].astype('datetime64[ns]')

# %%
data.dtypes
# Out:
# Date                datetime64[ns]
# Day                          int64
# Month                       object
# Year                         int64
# Customer_Age                 int64
# Age_Group                   object
# Customer_Gender             object
# Country                     object
# State                       object
# Product_Category            object
# Sub_Category                object
# Product                     object
# Order_Quantity               int64
# Unit_Cost                    int64
# Unit_Price                   int64
# Profit                       int64
# Cost                         int64
# Revenue                      int64
# dtype: object

# %%
data.head(3)
# Out:
#         Date  Day Month  Year  Customer_Age             Age_Group  \
# 0 2018-07-01    1  July  2018            33  Young Adults (25-34)
# 1 2018-07-01    1  July  2018            41        Adults (35-64)
# 2 2018-07-01    1  July  2018            33  Young Adults (25-34)
#
#   Customer_Gender        Country       State Product_Category  \
# 0               F  United States  Washington      Accessories
# 1               M        Germany      Hessen      Accessories
# 2               F  United States  Washington      Accessories
#
#         Sub_Category              Product  Order_Quantity  Unit_Cost  \
# 0    Tires and Tubes  Patch Kit/8 Patches              30          1
# 1  Bottles and Cages     Road Bottle Cage              28          3
# 2    Tires and Tubes  Patch Kit/8 Patches              24          1
#
#    Unit_Price  Profit  Cost  Revenue
# 0           2      30    30       60
# 1           9     168    84      252
# 2           2      24    24       48

# %%
data['Motiv']=data['Date'].dt.month

# %%
data.head(3)
# Out:
#         Date  Day Month  Year  Customer_Age             Age_Group  \
# 0 2018-07-01    1  July  2018            33  Young Adults (25-34)
# 1 2018-07-01    1  July  2018            41        Adults (35-64)
# 2 2018-07-01    1  July  2018            33  Young Adults (25-34)
#
#   Customer_Gender        Country       State Product_Category  \
# 0               F  United States  Washington      Accessories
# 1               M        Germany      Hessen      Accessories
# 2               F  United States  Washington      Accessories
#
#         Sub_Category              Product  Order_Quantity  Unit_Cost  \
# 0    Tires and Tubes  Patch Kit/8 Patches              30          1
# 1  Bottles and Cages     Road Bottle Cage              28          3
# 2    Tires and Tubes  Patch Kit/8 Patches              24          1
#
#    Unit_Price  Profit  Cost  Revenue  Motiv
# 0           2      30    30       60      7
# 1           9     168    84      252      7
# ...

# %%
data['Country']=data['Country'].astype(str)

# %%
data['CutCountry']=data['Country'].str[:3]

# %%
data.tail(5)
# Out:
#             Date  Day Month  Year  Customer_Age       Age_Group  \
# 69402 2021-07-31   31  July  2021            36  Adults (35-64)
# 69403 2021-07-31   31  July  2021            44  Adults (35-64)
# 69404 2021-07-31   31  July  2021            17     Youth (<25)
# 69405 2021-07-31   31  July  2021            19     Youth (<25)
# 69406 2021-07-31   31  July  2021            21     Youth (<25)
#
#       Customer_Gender         Country             State Product_Category  \
# 69402               F   United States        Washington      Accessories
# 69403               F  United Kingdom           England      Accessories
# 69404               M          Canada  British Columbia      Accessories
# 69405               M          Canada  British Columbia      Accessories
# 69406               F       Australia   New South Wales      Accessories
#
#           Sub_Category                Product  Order_Quantity  Unit_Cost  \
# ...

# %%
data['Profit&Cost']=data['Profit'].fillna(0) + data['Cost'].fillna(0)

# %%
data['Rev-Profit']=data['Revenue']-data['Profit']

# %%
data.head(5)
# Out:
#         Date  Day Month  Year  Customer_Age             Age_Group  \
# 0 2018-07-01    1  July  2018            33  Young Adults (25-34)
# 1 2018-07-01    1  July  2018            41        Adults (35-64)
# 2 2018-07-01    1  July  2018            33  Young Adults (25-34)
# 3 2018-07-01    1  July  2018            37        Adults (35-64)
# 4 2018-07-01    1  July  2018            30  Young Adults (25-34)
#
#   Customer_Gender        Country                State Product_Category  ...  \
# 0               F  United States           Washington      Accessories  ...
# 1               M        Germany               Hessen      Accessories  ...
# 2               F  United States           Washington      Accessories  ...
# 3               M         France                 Nord      Accessories  ...
# 4               F        Germany  Nordrhein-Westfalen      Accessories  ...
#
#   Order_Quantity Unit_Cost  Unit_Price  Profit  Cost  Revenue  Motiv  \
# ...

# %%
USA=data[data['Country']=='United States']
USA
# Out:
#             Date  Day Month  Year  Customer_Age             Age_Group  \
# 0     2018-07-01    1  July  2018            33  Young Adults (25-34)
# 2     2018-07-01    1  July  2018            33  Young Adults (25-34)
# 11    2018-07-01    1  July  2018            30  Young Adults (25-34)
# 16    2018-07-01    1  July  2018            29  Young Adults (25-34)
# 20    2018-07-02    2  July  2018            35        Adults (35-64)
# ...          ...  ...   ...   ...           ...                   ...
# 69393 2021-07-31   31  July  2021            39        Adults (35-64)
# 69396 2021-07-31   31  July  2021            36        Adults (35-64)
# 69397 2021-07-31   31  July  2021            39        Adults (35-64)
# 69398 2021-07-31   31  July  2021            40        Adults (35-64)
# 69402 2021-07-31   31  July  2021            36        Adults (35-64)
#
#       Customer_Gender        Country       State Product_Category  ...  \
# ...

# %%
USA_Rev_by_state=USA.groupby('State')['Revenue'].agg(['sum','mean'])
USA_Rev_by_state
# Out:
#                     sum        mean
# State
# Alabama             210   52.500000
# Arizona              99   49.500000
# California      2085061  148.371237
# Florida            1573  157.300000
# Georgia            1257  209.500000
# Illinois           5453  227.208333
# Kentucky           1202  240.400000
# Minnesota           208   52.000000
# Mississippi         240  120.000000
# Missouri            646  161.500000
# Montana            2278  379.666667
# New York           4331  254.764706
# North Carolina      465  116.250000
# Ohio               3944  179.272727
# Oregon           487952  142.550979
# South Carolina     1514  151.400000
# Texas              2192   91.333333
# Utah               1035  172.500000
# Virginia            120   60.000000
# Washington       998666  136.020975
# Wyoming             207  103.500000

# %%
USA.dtypes
# Out:
# Date                datetime64[ns]
# Day                          int64
# Month                       object
# Year                         int64
# Customer_Age                 int64
# Age_Group                   object
# Customer_Gender             object
# Country                     object
# State                       object
# Product_Category            object
# Sub_Category                object
# Product                     object
# Order_Quantity               int64
# Unit_Cost                    int64
# Unit_Price                   int64
# Profit                       int64
# Cost                         int64
# Revenue                      int64
# Motiv                        int32
# CutCountry                  object
# Profit&Cost                  int64
# Rev-Profit                   int64
# dtype: object

# %%
NewUSA=USA[['State','Revenue','Profit','Product_Category']]
NewUSA
# Out:
#             State  Revenue  Profit Product_Category
# 0      Washington       60      30      Accessories
# 2      Washington       48      24      Accessories
# 11     California      200     128      Accessories
# 16         Oregon      108      24         Clothing
# 20     California      261      58         Clothing
# ...           ...      ...     ...              ...
# 69393  California      330     204      Accessories
# 69396  Washington       25      15      Accessories
# 69397  California       40      25      Accessories
# 69398  Washington        8       4      Accessories
# 69402  Washington       15       9      Accessories
#
# [24972 rows x 4 columns]

# %%
#univariate analysis
#continuous histogram
plt.figure(figsize=(12,8))
sns.histplot(data=data,x='Revenue',bins=20,kde=True,color='green')
plt.title('Hostogram of revenue')
plt.show()

# %%
#boxplot
plt.figure(figsize=(12,8))
sns.boxplot(data=data,y='Profit',color='green')
plt.title('Boxplot of profit')
plt.show()

# %%
#countplot for categorical data
plt.figure(figsize=(12,8))
sns.countplot(data=data,x='Country',palette='viridis')
plt.title('Seeing the different countries')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10544\2748935943.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data,x='Country',palette='viridis')

# %%
#cont vs cont
plt.figure(figsize=(12,8))
sns.scatterplot(data=data,x='Cost',y='Revenue',alpha=0.6,color='green')
plt.title('Does revenue increase when cost increases?')
plt.xlabel('Cost')
plt.ylabel('Revenue')
plt.show()

# %%
#cont vs cat
plt.figure(figsize=(12,8))
sns.boxplot(data=data,x='Country',y='Revenue',palette='viridis')
plt.title('Revenue in different countries')
plt.xlabel('Countries')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10544\391009962.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data,x='Country',y='Revenue',palette='viridis')

# %%
data['Year'].dtype
# Out:
# dtype('int64')

# %%
data['Year']=data['Year'].astype('int')

# %%
rev_years=data.groupby('Year')['Revenue'].sum()
rev_years
# Out:
# Year
# 2018    2161631
# 2019    2891422
# 2020    2144069
# 2021    2856459
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=data,x='Year',y='Revenue',color='green')
plt.title('Revenue over the years')
plt.xlabel('Years')
plt.ylabel('Revenue')
plt.show()

# %%
#cat vs cat
pivoted=pd.crosstab(data['Country'], data['State'])
pivoted
# Out:
# State           Alabama  Alberta  Arizona  Bayern  Brandenburg  \
# Country
# Australia             0        0        0       0            0
# Canada                0       33        0       0            0
# France                0        0        0       0            0
# Germany               0        0        0     824          103
# United Kingdom        0        0        0       0            0
# United States         4        0        2       0            0
#
# State           British Columbia  California  Charente-Maritime  England  \
# Country
# Australia                      0           0                  0        0
# Canada                     10151           0                  0        0
# France                         0           0                 91        0
# Germany                        0           0                  0        0
# United Kingdom                 0           0                  0     8036
# ...

# %%
pivoted.plot(kind='bar',stacked=True,figsize=(12,8),colormap='viridis')
plt.title('State by country')
plt.xlabel('Country')
plt.ylabel('State')
plt.legend('State')
plt.xticks(rotation=45)
plt.show()

# %%
#cat vs cat
pivoted1=pd.crosstab(data['Country'], data['Age_Group'])
pivoted1
# Out:
# Age_Group       Adults (35-64)  Seniors (64+)  Young Adults (25-34)  \
# Country
# Australia                 5539             14                  5408
# Canada                    4843             60                  3381
# France                    2905              4                  2495
# Germany                   2828              0                  2351
# United Kingdom            4036              8                  2616
# United States            13984             65                  6764
#
# Age_Group       Youth (<25)
# Country
# Australia              2465
# Canada                 1906
# France                 1082
# Germany                1118
# United Kingdom         1376
# United States          4159

# %%
pivoted1.plot(kind='bar',stacked=True,figsize=(12,8),colormap='viridis')
plt.title('Age_Group by country')
plt.xlabel('Country')
plt.ylabel('Age_Group')
plt.legend('Age_Group')
plt.xticks(rotation=45)
plt.show()

# %%
#multivariate
plt.figure(figsize=(12,8))
sns.heatmap(data[['Revenue','Cost','Profit','Year']].corr(),annot=True,cmap='viridis',fmt='.2f')
plt.title('Heatmap of the data')
plt.show()
